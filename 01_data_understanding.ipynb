# %% [markdown]
# # Amazon E-Commerce Sales Analysis
# ### Notebook 1 - Data Understanding
#
# **Objective:** Understand the Structure , Content, and Quality of the Amazon Sales Dataseet before any cleaning and analysis.
#
# **Dataset:** Amazon Sales Report.csv
# **Total Rows:** 128,976
# **Source:** Kaggle - E-Commerce Sales Dataset
#
# ---

# %%
# ==========================================================
# STEP 1: IMPORT LIBRARIES
# ==========================================================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("All libraries imported successfully!")
# Out:
# All libraries imported successfully!

# %%
# ==========================================================
# STEP 2: LOAD THE DATASET
# ==========================================================

df = pd.read_csv(r'C:\Users\pushp\OneDrive\Documents\Desktop\E-commerce sales\Amazon Sale Report.csv',
                 encoding='latin1')

print("Dataset loaded successfully!")
print(f"Total Rows: {df.shape[0]}")
print(f"Total Columns: {df.shape[1]}")
# Out:
# C:\Users\pushp\AppData\Local\Temp\ipykernel_24392\3947217496.py:5: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'C:\Users\pushp\OneDrive\Documents\Desktop\E-commerce sales\Amazon Sale Report.csv',
# Dataset loaded successfully!
# Total Rows: 128975
# Total Columns: 24

# %%
# ==========================================================
# STEP 3: FIRST LOOK AT THE DATA
# ==========================================================

print("----- first 5 rows of the dataset -----")
df.head()
# Out:
# ----- first 5 rows of the dataset -----
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
# ...

# %%
# ==========================================================
# STEP 4: DATASET INFORMATION
# ==========================================================

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  object
#  2   Date                128975 non-null  object
#  3   Status              128975 non-null  object
#  4   Fulfilment          128975 non-null  object
#  5   Sales Channel       128975 non-null  object
#  6   ship-service-level  128975 non-null  object
#  7   Style               128975 non-null  object
#  8   SKU                 128975 non-null  object
#  9   Category            128975 non-null  object
#  10  Size                128975 non-null  object
#  11  ASIN                128975 non-null  object
#  12  Courier Status      122103 non-null  object
#  13  Qty                 128975 non-null  int64
#  14  currency            121180 non-null  object
# ...

# %%
# ==========================================================
# STEP 5: STATISTICAL SUMMARY
# ==========================================================
df.describe()
# Out:
#                index            Qty         Amount  ship-postal-code
# count  128975.000000  128975.000000  121180.000000     128942.000000
# mean    64487.000000       0.904431     648.561465     463966.236509
# std     37232.019822       0.313354     281.211687     191476.764941
# min         0.000000       0.000000       0.000000     110001.000000
# 25%     32243.500000       1.000000     449.000000     382421.000000
# 50%     64487.000000       1.000000     605.000000     500033.000000
# 75%     96730.500000       1.000000     788.000000     600024.000000
# max    128974.000000      15.000000    5584.000000     989898.000000

# %%
df.describe(include='all')
# Out:
#                 index             Order ID      Date   Status Fulfilment  \
# count   128975.000000               128975    128975   128975     128975
# unique            NaN               120378        91       13          2
# top               NaN  171-5057375-2831560  05-03-22  Shipped     Amazon
# freq              NaN                   12      2085    77804      89698
# mean     64487.000000                  NaN       NaN      NaN        NaN
# std      37232.019822                  NaN       NaN      NaN        NaN
# min          0.000000                  NaN       NaN      NaN        NaN
# 25%      32243.500000                  NaN       NaN      NaN        NaN
# 50%      64487.000000                  NaN       NaN      NaN        NaN
# 75%      96730.500000                  NaN       NaN      NaN        NaN
# max     128974.000000                  NaN       NaN      NaN        NaN
#
#        Sales Channel  ship-service-level    Style           SKU Category  ...  \
# ...

# %% [markdown]
# ## Summary — Data Understanding
#
# ### Dataset Overview
# - Total Rows: 128,975
# - Total Columns: 24
# - Memory Usage: 22.8 MB
#
# ### Key Issues Found
# 1. Amount and Currency columns — 7,795 missing values
# 2. Fulfilled-by column — 89,698 missing values (mostly empty)
# 3. Unnamed: 22 column — garbage column, to be deleted
# 4. Date column — stored as text, needs datetime conversion
# 5. Amount minimum = 0.0 — zero value orders need investigation
# 6. Qty minimum = 0.0 — zero quantity orders need removal
#
# ### Key Business Observations
# - Average order value = ₹648
# - 75% of orders are below ₹788 (budget-mid range market)
# - Maximum single order = ₹5,584
# - Most popular categories: Kurta, Set, Western Dress
#
# ### Next Step → Data Cleaning
